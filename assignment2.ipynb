# %% [markdown]
# # **Data Types and Structures Questions**
#
# 1) What are data structures, and why are they important?
# -->Data structures are a way of organizing and storing data in a computer so that it can be used efficiently.make the code more efficient, and make the code easier to understand.
#
#
# 2)Explain the difference between mutable and immutable data types with examples.
# -->Mutable data types are those whose values can be changed after they are created, while immutable data types cannot be modified once created.
# example:->
#                          mutable:
#           my_dict = {"name": "mondira", "age":25}
#     my_dict["age"] = 25  # Modify the value associated with the "age" key
#     my_dict["city"] = "kolkata"  # Add a new key-value pair
#     print(my_dict)  # Output: {'name': 'mondira', 'age': 25, 'city': 'kolkata'}
#
#                         immutable:
#          my_tuple = (1, 2, 3)
#     # my_tuple[0] = 4  # This will raise an error because tuples are immutable
#     my_tuple = (4,) + my_tuple[1:]  # Create a new tuple
#     print(my_tuple)  # Output: (4, 2, 3)
#
# 3)What are the main differences between lists and tuples in Python?
# -->Lists
# are mutable, meaning their contents can be changed after creation. You can add, remove, or modify elements within a list.
# Tuples
# are immutable, meaning their contents cannot be changed once they are created.
#
# 4)Describe how dictionaries store data.
# -->data is stored in dict key:value format.
#
# 5)Why might you use a set instead of a list in Python?
# -->One of the main advantages of using sets in Python is that they are highly optimized for membership tests.
#
# 6)What is a string in Python, and how is it different from a list?
# -->In Python, strings are used for representing textual data.A list is a sequence of items, where each item could be anything.
#
# 7)How do tuples ensure data integrity in Python?
# -->Tuples in Python are immutable, meaning once they are created, they cannot be changed. This characteristic can be leveraged for data integrity by using tuples for data that should not be modified after creation.
#
# 8)What is a hash table, and how does it relate to dictionaries in Python?
# -->In Python, the Dictionary data types represent the implementation of hash tables. The Keys in the dictionary are hashable–they are generated by a hash function which generates a unique result for each unique value supplied to the hash function.
#
# 9)Can lists contain different data types in Python?
# -->Yes, lists in Python can contain elements of different data types.
#
# 10)Explain why strings are immutable in Python.
# -->In Python, strings are immutable, which means that once a string is created, its value cannot be changed. Any operation that appears to modify a string actually creates a new string object.
# Immutable strings are thread-safe, which means that they can be accessed and used by multiple threads without any risk of data corruption. This is because immutable objects cannot be modified by any thread once they have been created.
#
# 11) What advantages do dictionaries offer over lists for certain tasks?
# -->Dictionaries excel in scenarios requiring fast lookups, key-value associations, and complex data mappings, while lists are ideal for ordered collections, sequential processing, and simple data storage.
#
# 12) Describe a scenario where using a tuple would be preferable over a list.
# -->Tuples are immutable.they are primarily used to store data that doesn't change frequently. Any operation can store data in a tuple when you don't want it to change. Tuples are great to use if you want the data in your collection to be read-only, never to change, and always remain the same and constant.
#
# 13)How do sets handle duplicate values in Python?
# --> sets in Python are unordered collections of unique elements. By their nature, duplicates aren't allowed. Therefore, converting a list into a set removes the duplicates.
#
# my_set = {1, 2, 2, 3, 4, 4, 5}
# print(my_set)  # Output: {1, 2, 3, 4, 5}
#
# my_set.add(3)
# print(my_set) # Output: {1, 2, 3, 4, 5}
#
# my_set.add(6)
# print(my_set) # Output: {1, 2, 3, 4, 5, 6}
#
#
# 14)How does the “in” keyword work differently for lists and dictionaries?
# -->For lists "in" keyword can be used to test whether certain characters are present in a string or a certain value present in a list or tuple.
# On the other hand, for dictionaries "in" keyword used to test whether something appears as a key. Actually the "in" operator uses different algorithms for lists and dictionaries.
#
# 15)Can you modify the elements of a tuple? Explain why or why not.
# -->No, we cannot directly modify the elements of a tuple after it has been created, Because tuples are designed to be immutable, which is a fundamental characteristic, so once they are created, we cannot change, add, or remove their elements.
# If we try to modify or attempt to change an element of a tuple, it will raise a TypeError.
#
# 16)What is a nested dictionary, and give an example of its use case?
# -->A nested dictionary is a dictionary where the values are themselves dictionaries, which means putting a dictionary inside another dictionary. This Dictionaries are used to store data values in key:value pairs. It is a collection which is ordered*, changeable and do not allow duplicates.
# # Outer dictionary
# employees = {
#     "department1": {
#         "employee1": {"name": "Alice", "position": "Software Engineer"},
#         "employee2": {"name": "Bob", "position": "Data Analyst"}
#     },
#     "department2": {
#         "employee3": {"name": "Charlie", "position": "Project Manager"},
#         "employee4": {"name": "David", "position": "UI/UX Designer"}
#     }
# }
#
# # Accessing nested values:
# print(employees["department1"]["employee1"]["name"]) # Output: Alice
# print(employees["department2"]["employee3"]["position"]) # Output: Project Manager
#
#
# 17)Describe the time complexity of accessing elements in a dictionary.
# -->The time complexity of retrieving a value by its key in a dictionary is O(1), which means it takes constant time regardless of the dictionary's size.this is because dictionaries use a hash table internally which allows for direct lookup of elements based on their key.
#
# 18)In what situations are lists preferred over dictionaries?
# --> For ordered collections and sequence operations, such as maintaining a stack or queue, lists are preferred over dictionaries. beacause Lists are faster for index-based access.
#
# 19)Why are dictionaries considered unordered, and how does that affect data retrieval?
# -->Dictionaries are considered unordered because they are implemented using hash tables, which do not guarantee that the order of items will be the same as the order they were inserted.
# As an affect of unordered dictionaries data retrieval provides much quicker access to unordered data than searching through the data set using a linear search, and it will also outperform a binary search.
#
# 20)Explain the difference between a list and a dictionary in terms of data retrieval.
# -->In terms of data retrieval,
# Lists are accessed by index, While Dictionaries are accessed by key.
# Lists: Use a numerical index (position) to retrieve elements.
# Dictionaries: Use a key to retrieve associated values.

# %%
#(1) Write a code to create a string with your name and print it.
name = "pritam"
print(name)

#(2) Write a code to find the length of the string "Hello World".
print(len("pritam"))

#(3) Write a code to slice the first 3 characters from the string "Python Programming".
txt = "pwskills"
sliced_txt = txt[:3]
print(sliced_txt)

#(4) Write a code to convert the string "hello" to uppercase.
case = "pritam"
upper_case = case.upper()
print(upper_case)

#(5) Write a code to replace the word "apple" with "orange" in the string "I like apple".
txt = "i like apple"
txt1 = txt.replace("apple","orange")
print(txt1)

#(6)  Write a code to create a list with numbers 1 to 5 and print it.
list = [1,2,3,4,5]
print(list)

#(7)  Write a code to append the number 10 to the list [1, 2, 3, 4].
list = [1,2,3,4]
list.append(10)
print(list)

#(8) Write a code to remove the number 3 from the list [1, 2, 3, 4, 5].
list = [1,2,3,4]
list.remove(3)
print(list)

#(9)  Write a code to access the second element in the list ['a', 'b', 'c', 'd'].
list = ["a","b","c","d"]
print(list[1])

#(10) Write a code to reverse the list [10, 20, 30, 40, 50].
list = [10,20,30,40,50]
list.reverse()
print(list)

#(11) Write a code to create a tuple with the elements 100, 200, 300 and print it.
tuple = (100,200,300)
print(tuple)

#(12) Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow').
tuple1 = ("red","green","blue","yellow")
print(tuple1[1:])

#(13)  Write a code to find the minimum number in the tuple (10, 20, 5, 15).
num = (10, 20, 5, 15)
print(min(num))

#(14)  Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').
find = ('dog', 'cat', 'rabbit')
find_index = find.index("cat")
print(find_index)

#(15) Write a code to create a tuple containing three different fruits and check if "kiwi" is in it.
tuple8 = ("apple","banana","mango","kiwi","orange")
if "kiwi" in tuple8:
  print("ok")

#(16)  Write a code to create a set with the elements 'a', 'b', 'c' and print it.
my_set = {'a', 'b', 'c'}
print(my_set)

#(17)  Write a code to clear all elements from the set {1, 2, 3, 4, 5}.
set = {1, 2, 3, 4, 5}
set.clear()
print(set)

#(18) Write a code to remove the element 4 from the set {1, 2, 3, 4}.
set1 = {1, 2, 3, 4}
set1.remove(4)
print(set1)

#(19) Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}.
s1 = {1,2,3}
s2 = {3,4,5}
print(s1|s2)

#(20) Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}.
set4 = {1,2,3}
set5 = {2,3,4}
print(set4 & set5)

#(21) Write a code to create a dictionary with the keys "name", "age", and "city", and print it.
my_dict = {"name":"pritam","age":25,"city":"kolkata"}
print(my_dict)

#(22) Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}.
my_dict5 = {"name":"john","age":25}
my_dict5["country"] = "USA"
print(my_dict5)

#(23) Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}
dict4 = {'name': 'Alice', 'age': 30}
print(dict4["name"])

#(24) Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}.
dict8 =  {'name': 'Bob', 'age': 22, 'city': 'New York'}
value = dict8.pop("age")
print(value)

#(25)  Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}.
dict_fav = {'name': 'Alice', 'city': 'Paris'}
if "city" in dict_fav:
  print("ok")
else:
  print("not ok")

#(26) Write a code to create a list, a tuple, and a dictionary, and print them all.
fav_list = [1,2,"gb",5]
fav_tuple = (1,1,2,3,"pritam")
fav_dict = {1,8,5,6,1,"pw skills"}

print(fav_list)
print(fav_tuple)
print(fav_dict)

#(27) Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the result.(replaced)
import random

random_numbers = [random.randint(1, 100) for i in range(5)]

random_numbers.sort()

print(random_numbers)

#(28) Write a code to create a list with strings and print the element at the third index.
listr = ["pw","skills","school","colage","hotel"]
print(listr[2])

#(29) Write a code to combine two dictionaries into one and print the result.
stud = {1,2,3,4}
stud1 = {5,6,7,8}
print(stud | stud1)

#(30) Write a code to convert a list of strings into a set.
"""
# !!!!!!
"""
# Out:
# pritam
# 6
# pws
# PRITAM
# i like orange
# [1, 2, 3, 4, 5]
# [1, 2, 3, 4, 10]
# [1, 2, 4]
# b
# [50, 40, 30, 20, 10]
# (100, 200, 300)
# ('green', 'blue', 'yellow')
# 5
# 1
# ok
# {'a', 'b', 'c'}
# set()
# {1, 2, 3}
# {1, 2, 3, 4, 5}
# {2, 3}
# {'name': 'pritam', 'age': 25, 'city': 'kolkata'}
# {'name': 'john', 'age': 25, 'country': 'USA'}
# Alice
# 22
# ok
# [1, 2, 'gb', 5]
# (1, 1, 2, 3, 'pritam')
# {'pw skills', 1, 5, 6, 8}
# [24, 34, 61, 94, 98]
# school
# {1, 2, 3, 4, 5, 6, 7, 8}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-2993011897> in <cell line: 0>()
#     144 #(30) Write a code to convert a list of strings into a set.
#     145 string_list = ["apple", "banana", "apple", "orange", "banana"]
# --> 146 string_set = list_to_set(string_list)
#     147 print(string_set)
#     148
#
# NameError: name 'list_to_set' is not defined
